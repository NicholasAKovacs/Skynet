# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sns
from pathlib import Path
from matplotlib.dates import YearLocator, DateFormatter

results_output_path = Path('../results/covid_recovery/')
results_output_path.joinpath('figures').mkdir(parents=True, exist_ok=True)

# %%
data_file = Path('../data/T100_domestic/processed/final_enriched_t100_data.parquet')
df = pd.read_parquet(data_file)

# %%
df
# Out:
#           PASSENGERS  FREIGHT  MAIL  DISTANCE UNIQUE_CARRIER  AIRLINE_ID  \
# 0                  0        0     0         0             HP       19991
# 1                  0        0     0         0             HP       19991
# 2                  0        0     0         0             HP       19991
# 3                  0        0     0         0             HP       19991
# 4                  0        0     0         0             HP       19991
# ...              ...      ...   ...       ...            ...         ...
# 10179062       83663    87134   210       404             DL       19790
# 10179063       84275   562218     5       404             DL       19790
# 10179064       84832   204449     0       404             DL       19790
# 10179065       86078    58485     0       404             DL       19790
# 10179066       87551   125302     0       404             DL       19790
#
#                  UNIQUE_CARRIER_NAME UNIQUE_CARRIER_ENTITY REGION CARRIER  \
# 0         America West Airlines Inc.                 06049      D      HP
# 1         America West Airlines Inc.                 06049      D      HP
# 2         America West Airlines Inc.                 06049      D      HP
# 3         America West Airlines Inc.                 06049      D      HP
# 4         America West Airlines Inc.                 06049      D      HP
# ...                              ...                   ...    ...     ...
# 10179062        Delta Air Lines Inc.                 01260      D      DL
# 10179063        Delta Air Lines Inc.                 01260      D      DL
# 10179064        Delta Air Lines Inc.                 01260      D      DL
# 10179065        Delta Air Lines Inc.                 01260      D      DL
# 10179066        Delta Air Lines Inc.                 01260      D      DL
#
#           ... origin_tourism_arrivals  origin_trade_pct_gdp  \
# 0         ...              79732000.0             15.270116
# 1         ...              79732000.0             15.270116
# 2         ...              79732000.0             15.270116
# 3         ...              79732000.0             15.270116
# 4         ...              79732000.0             15.270116
# ...       ...                     ...                   ...
# 10179062  ...                     NaN                   NaN
# 10179063  ...                     NaN                   NaN
# 10179064  ...                     NaN                   NaN
# 10179065  ...                     NaN                   NaN
# 10179066  ...                     NaN                   NaN
#
#           dest_inflation_cp      dest_gdp  dest_gdp_per_capita  \
# 0                  5.397956  5.963144e+12         23888.600009
# 1                  5.397956  5.963144e+12         23888.600009
# 2                  5.397956  5.963144e+12         23888.600009
# 3                  5.397956  5.963144e+12         23888.600009
# 4                  5.397956  5.963144e+12         23888.600009
# ...                     ...           ...                  ...
# 10179062                NaN           NaN                  NaN
# 10179063                NaN           NaN                  NaN
# 10179064                NaN           NaN                  NaN
# 10179065                NaN           NaN                  NaN
# 10179066                NaN           NaN                  NaN
#
#           dest_population dest_tourism_arrivals dest_trade_pct_gdp  \
# 0             249623000.0            79732000.0          15.270116
# 1             249623000.0            79732000.0          15.270116
# 2             249623000.0            79732000.0          15.270116
# 3             249623000.0            79732000.0          15.270116
# 4             249623000.0            79732000.0          15.270116
# ...                   ...                   ...                ...
# 10179062              NaN                   NaN                NaN
# 10179063              NaN                   NaN                NaN
# 10179064              NaN                   NaN                NaN
# 10179065              NaN                   NaN                NaN
# 10179066              NaN                   NaN                NaN
#
#          U.S. Gulf Coast Kerosene-Type Jet Fuel Spot Price FOB (Dollars per Gallon)  \
# 0                                                     0.494
# 1                                                     0.971
# 2                                                     0.535
# 3                                                     0.791
# 4                                                     0.494
# ...                                                     ...
# 10179062                                              2.094
# 10179063                                              2.069
# 10179064                                              2.069
# 10179065                                              1.928
# 10179066                                              1.928
#
#           Travel_type
# 0            Domestic
# 1            Domestic
# 2            Domestic
# 3            Domestic
# 4            Domestic
# ...               ...
# 10179062     Domestic
# 10179063     Domestic
# 10179064     Domestic
# 10179065     Domestic
# 10179066     Domestic
#
# [10124155 rows x 69 columns]
