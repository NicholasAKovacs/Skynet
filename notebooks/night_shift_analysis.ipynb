# %% [markdown]
# # Night Shift Analysis: Recovery Metrics
#
# **Author:** Nick's SecrAItary
# **Date:** 2026-02-03
#
# This notebook implements a standardized 'Recovery Rate' metric to quantify the Africa vs. Asia divergence.

# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Add scripts to path
sys.path.append('../scripts')
from metrics import calculate_recovery_rate

# %% [markdown]
# ## Load Data (Placeholder)
# Loading the processed parquet file.

# %%
# Example usage pattern
# df = pd.read_parquet('../data/T100_International/processed/some_file.parquet')
# df_recovery = calculate_recovery_rate(df, value_col='Passengers', baseline_year=2019)
# 
# plt.figure(figsize=(12, 6))
# sns.lineplot(data=df_recovery, x='Date', y='recovery_rate', hue='Region')
# plt.axhline(1.0, linestyle='--', color='red', label='Pre-Pandemic Baseline')
# plt.title('Recovery Rate by Region (2019 Baseline)')
